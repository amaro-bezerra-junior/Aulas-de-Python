# %%
import pandas as pd

# %%
print('Realizando Leitura dos Arquivos...')
# Out:
# Realizando Leitura dos Arquivos...

# %%
df_detalhamento1 = pd.read_excel('detalhamento.xlsx', sheet_name = 'AM', skiprows= 1)

# %%
df_detalhamento2 = pd.read_excel('detalhamento.xlsx', sheet_name = 'RR', skiprows= 1)

# %%
df_detalhamento3 = pd.read_excel('detalhamento.xlsx', sheet_name = 'RO', skiprows= 1)

# %%
df_detalhamento4 = pd.read_excel('detalhamento.xlsx', sheet_name = 'AC', skiprows= 1)

# %%
df_vendas = pd.read_csv('vendas.csv', sep = '|', skiprows = 0, encoding = 'utf-8')

# %%
df_detalhamento1
# Out:
#        NomeFantasia  Escritório de vendas  UF Operadora  Vlookup Bruto
# 0     BEMOL AVENIDA                   103  AM     Claro           2651
# 1     BEMOL AVENIDA                   103  AM        Oi           3309
# 2     BEMOL AVENIDA                   103  AM       Tim           1550
# 3     BEMOL AVENIDA                   103  AM      Vivo           4739
# 4     BEMOL BARROSO                   107  AM     Claro           1495
# ..              ...                   ...  ..       ...            ...
# 121  BEMOL STUDIO 5                   116  AM      Vivo           2144
# 122  BEMOL TORQUATO                   500  AM     Claro           1838
# 123  BEMOL TORQUATO                   500  AM        Oi            875
# 124  BEMOL TORQUATO                   500  AM       Tim            560
# 125  BEMOL TORQUATO                   500  AM      Vivo           3751
#
# [126 rows x 5 columns]

# %%
df_detalhamento2
# Out:
#             NomeFantasia  Escritório de vendas  UF Operadora  Vlookup Bruto
# 0        BEMOL BOA VISTA                   701  RR     Claro            140
# 1        BEMOL BOA VISTA                   701  RR        Oi             20
# 2        BEMOL BOA VISTA                   701  RR       Tim            135
# 3        BEMOL BOA VISTA                   701  RR      Vivo            304
# 4  BEMOL FARMA BOA VISTA                   610  RR     Claro            260
# 5  BEMOL FARMA BOA VISTA                   610  RR        Oi            135
# 6  BEMOL FARMA BOA VISTA                   610  RR       Tim            540
# 7  BEMOL FARMA BOA VISTA                   610  RR      Vivo           1400

# %%
df_detalhamento3
# Out:
#                   NomeFantasia  Escritório de vendas  ... Operadora Vlookup Bruto
# 0      BEMOL FARMA PORTO VELHO                   609  ...     Claro           486
# 1      BEMOL FARMA PORTO VELHO                   609  ...        Oi            90
# 2      BEMOL FARMA PORTO VELHO                   609  ...       Tim            90
# 3      BEMOL FARMA PORTO VELHO                   609  ...      Vivo            60
# 4            BEMOL PORTO VELHO                   201  ...     Claro          1585
# 5            BEMOL PORTO VELHO                   201  ...        Oi           634
# 6            BEMOL PORTO VELHO                   201  ...       Tim           520
# 7            BEMOL PORTO VELHO                   201  ...      Vivo           521
# 8   BEMOL PORTO VELHO SHOPPING                   202  ...     Claro          2399
# 9   BEMOL PORTO VELHO SHOPPING                   202  ...        Oi           602
# 10  BEMOL PORTO VELHO SHOPPING                   202  ...       Tim           310
# 11  BEMOL PORTO VELHO SHOPPING                   202  ...      Vivo           447
# 12        LOJA BEMOL ARIQUEMES                   206  ...     Claro            45
# 13        LOJA BEMOL ARIQUEMES                   206  ...        Oi            40
# 14        LOJA BEMOL ARIQUEMES                   206  ...      Vivo            15
# 15  LOJA BEMOL FARMA ARIQUEMES                   613  ...     Claro            90
# 16  LOJA BEMOL FARMA ARIQUEMES                   613  ...        Oi            70
# 17  LOJA BEMOL FARMA ARIQUEMES                   613  ...       Tim            35
# 18  LOJA BEMOL FARMA ARIQUEMES                   613  ...      Vivo            35
# 19  LOJA BEMOL FARMA JI PARANA                   616  ...     Claro           411
# 20  LOJA BEMOL FARMA JI PARANA                   616  ...        Oi            95
# 21  LOJA BEMOL FARMA JI PARANA                   616  ...       Tim            50
# 22  LOJA BEMOL FARMA JI PARANA                   616  ...      Vivo            70
# 23        LOJA BEMOL JI-PARANA                   205  ...     Claro           123
#
# [24 rows x 5 columns]

# %%
df_detalhamento4
# Out:
#        NomeFantasia  Escritório de vendas  UF Operadora  Valor Bruto
# 0  BEMOL RIO BRANCO                   401  AC     Claro          500
# 1  BEMOL RIO BRANCO                   401  AC        Oi          375
# 2  BEMOL RIO BRANCO                   401  AC       Tim          125
# 3  BEMOL RIO BRANCO                   401  AC      Vivo          343

# %%
df_vendas
# Out:
#       Escritório de vendas Fornecedor  ...        Data Valor Liquido
# 0                      101       Vivo  ...  02.01.2020          20.0
# 1                      101       Vivo  ...  30.12.2019          10.0
# 2                      101       Vivo  ...  04.01.2020          20.0
# 3                      101       Vivo  ...  02.01.2020          10.0
# 4                      101       Vivo  ...  03.01.2020          25.0
# ...                    ...        ...  ...         ...           ...
# 5108                   701      Claro  ...  30.12.2019          20.0
# 5109                   701      Claro  ...  04.01.2020          20.0
# 5110                   701      Claro  ...  05.01.2020          20.0
# 5111                   701      Claro  ...  05.01.2020          45.0
# 5112                   701      Claro  ...  04.01.2020          35.0
#
# [5113 rows x 5 columns]

# %%
print('Iniciando Tratamento das Informações...')
# Out:
# Iniciando Tratamento das Informações...

# %%
df_detalhamento1 = df_detalhamento1.rename(columns = {'NomeFantasia':'Loja','Escritório de vendas':'Escritório_de_Vendas', 'UF':'UF', 'Operadora':'Operadora', 'Vlookup Bruto':'Valor_Bruto'})

# %%
df_detalhamento2 = df_detalhamento2.rename(columns = {'NomeFantasia':'Loja','Escritório de vendas':'Escritório_de_Vendas', 'UF':'UF', 'Operadora':'Operadora', 'Vlookup Bruto':'Valor_Bruto'})

# %%
df_detalhamento3 = df_detalhamento3.rename(columns = {'NomeFantasia':'Loja','Escritório de vendas':'Escritório_de_Vendas', 'UF':'UF', 'Operadora':'Operadora', 'Vlookup Bruto':'Valor_Bruto'})

# %%
df_detalhamento4 = df_detalhamento4.rename(columns = {'NomeFantasia':'Loja','Escritório de vendas':'Escritório_de_Vendas', 'UF':'UF', 'Operadora':'Operadora', 'Valor Bruto':'Valor_Bruto'})

# %%
df_vendas = df_vendas.rename(columns = {'Escritório de vendas':'Escritório_de_Vendas', 'Fornecedor':'Operadora', 'Material':'Material', 'Data':'Data', 'Valor Liquido':'Valor_Liquido'})

# %%
df_detalhamento1
# Out:
#                Loja  Escritório_de_Vendas  UF Operadora  Valor_Bruto
# 0     BEMOL AVENIDA                   103  AM     Claro         2651
# 1     BEMOL AVENIDA                   103  AM        Oi         3309
# 2     BEMOL AVENIDA                   103  AM       Tim         1550
# 3     BEMOL AVENIDA                   103  AM      Vivo         4739
# 4     BEMOL BARROSO                   107  AM     Claro         1495
# ..              ...                   ...  ..       ...          ...
# 121  BEMOL STUDIO 5                   116  AM      Vivo         2144
# 122  BEMOL TORQUATO                   500  AM     Claro         1838
# 123  BEMOL TORQUATO                   500  AM        Oi          875
# 124  BEMOL TORQUATO                   500  AM       Tim          560
# 125  BEMOL TORQUATO                   500  AM      Vivo         3751
#
# [126 rows x 5 columns]

# %%
df_detalhamento2
# Out:
#                     Loja  Escritório_de_Vendas  UF Operadora  Valor_Bruto
# 0        BEMOL BOA VISTA                   701  RR     Claro          140
# 1        BEMOL BOA VISTA                   701  RR        Oi           20
# 2        BEMOL BOA VISTA                   701  RR       Tim          135
# 3        BEMOL BOA VISTA                   701  RR      Vivo          304
# 4  BEMOL FARMA BOA VISTA                   610  RR     Claro          260
# 5  BEMOL FARMA BOA VISTA                   610  RR        Oi          135
# 6  BEMOL FARMA BOA VISTA                   610  RR       Tim          540
# 7  BEMOL FARMA BOA VISTA                   610  RR      Vivo         1400

# %%
df_detalhamento3
# Out:
#                           Loja  Escritório_de_Vendas  UF Operadora  Valor_Bruto
# 0      BEMOL FARMA PORTO VELHO                   609  RO     Claro          486
# 1      BEMOL FARMA PORTO VELHO                   609  RO        Oi           90
# 2      BEMOL FARMA PORTO VELHO                   609  RO       Tim           90
# 3      BEMOL FARMA PORTO VELHO                   609  RO      Vivo           60
# 4            BEMOL PORTO VELHO                   201  RO     Claro         1585
# 5            BEMOL PORTO VELHO                   201  RO        Oi          634
# 6            BEMOL PORTO VELHO                   201  RO       Tim          520
# 7            BEMOL PORTO VELHO                   201  RO      Vivo          521
# 8   BEMOL PORTO VELHO SHOPPING                   202  RO     Claro         2399
# 9   BEMOL PORTO VELHO SHOPPING                   202  RO        Oi          602
# 10  BEMOL PORTO VELHO SHOPPING                   202  RO       Tim          310
# 11  BEMOL PORTO VELHO SHOPPING                   202  RO      Vivo          447
# 12        LOJA BEMOL ARIQUEMES                   206  RO     Claro           45
# 13        LOJA BEMOL ARIQUEMES                   206  RO        Oi           40
# 14        LOJA BEMOL ARIQUEMES                   206  RO      Vivo           15
# 15  LOJA BEMOL FARMA ARIQUEMES                   613  RO     Claro           90
# 16  LOJA BEMOL FARMA ARIQUEMES                   613  RO        Oi           70
# 17  LOJA BEMOL FARMA ARIQUEMES                   613  RO       Tim           35
# 18  LOJA BEMOL FARMA ARIQUEMES                   613  RO      Vivo           35
# 19  LOJA BEMOL FARMA JI PARANA                   616  RO     Claro          411
# 20  LOJA BEMOL FARMA JI PARANA                   616  RO        Oi           95
# 21  LOJA BEMOL FARMA JI PARANA                   616  RO       Tim           50
# 22  LOJA BEMOL FARMA JI PARANA                   616  RO      Vivo           70
# 23        LOJA BEMOL JI-PARANA                   205  RO     Claro          123

# %%
df_detalhamento4
# Out:
#                Loja  Escritório_de_Vendas  UF Operadora  Valor_Bruto
# 0  BEMOL RIO BRANCO                   401  AC     Claro          500
# 1  BEMOL RIO BRANCO                   401  AC        Oi          375
# 2  BEMOL RIO BRANCO                   401  AC       Tim          125
# 3  BEMOL RIO BRANCO                   401  AC      Vivo          343

# %%
df_vendas
# Out:
#       Escritório_de_Vendas Operadora  ...        Data Valor_Liquido
# 0                      101      Vivo  ...  02.01.2020          20.0
# 1                      101      Vivo  ...  30.12.2019          10.0
# 2                      101      Vivo  ...  04.01.2020          20.0
# 3                      101      Vivo  ...  02.01.2020          10.0
# 4                      101      Vivo  ...  03.01.2020          25.0
# ...                    ...       ...  ...         ...           ...
# 5108                   701     Claro  ...  30.12.2019          20.0
# 5109                   701     Claro  ...  04.01.2020          20.0
# 5110                   701     Claro  ...  05.01.2020          20.0
# 5111                   701     Claro  ...  05.01.2020          45.0
# 5112                   701     Claro  ...  04.01.2020          35.0
#
# [5113 rows x 5 columns]

# %%
df_detalhamento1 = df_detalhamento1.drop(['UF'], axis = 'columns')

# %%
df_detalhamento2 = df_detalhamento2.drop(['UF'], axis = 'columns')

# %%
df_detalhamento3 = df_detalhamento3.drop(['UF'], axis = 'columns')

# %%
df_detalhamento4 = df_detalhamento4.drop(['UF'], axis = 'columns')

# %%
df_vendas = df_vendas.drop(['Material', 'Data'], axis = 'columns')

# %%
df_detalhamento1
# Out:
#                Loja  Escritório_de_Vendas Operadora  Valor_Bruto
# 0     BEMOL AVENIDA                   103     Claro         2651
# 1     BEMOL AVENIDA                   103        Oi         3309
# 2     BEMOL AVENIDA                   103       Tim         1550
# 3     BEMOL AVENIDA                   103      Vivo         4739
# 4     BEMOL BARROSO                   107     Claro         1495
# ..              ...                   ...       ...          ...
# 121  BEMOL STUDIO 5                   116      Vivo         2144
# 122  BEMOL TORQUATO                   500     Claro         1838
# 123  BEMOL TORQUATO                   500        Oi          875
# 124  BEMOL TORQUATO                   500       Tim          560
# 125  BEMOL TORQUATO                   500      Vivo         3751
#
# [126 rows x 4 columns]

# %%
df_detalhamento2
# Out:
#                     Loja  Escritório_de_Vendas Operadora  Valor_Bruto
# 0        BEMOL BOA VISTA                   701     Claro          140
# 1        BEMOL BOA VISTA                   701        Oi           20
# 2        BEMOL BOA VISTA                   701       Tim          135
# 3        BEMOL BOA VISTA                   701      Vivo          304
# 4  BEMOL FARMA BOA VISTA                   610     Claro          260
# 5  BEMOL FARMA BOA VISTA                   610        Oi          135
# 6  BEMOL FARMA BOA VISTA                   610       Tim          540
# 7  BEMOL FARMA BOA VISTA                   610      Vivo         1400

# %%
df_detalhamento3
# Out:
#                           Loja  Escritório_de_Vendas Operadora  Valor_Bruto
# 0      BEMOL FARMA PORTO VELHO                   609     Claro          486
# 1      BEMOL FARMA PORTO VELHO                   609        Oi           90
# 2      BEMOL FARMA PORTO VELHO                   609       Tim           90
# 3      BEMOL FARMA PORTO VELHO                   609      Vivo           60
# 4            BEMOL PORTO VELHO                   201     Claro         1585
# 5            BEMOL PORTO VELHO                   201        Oi          634
# 6            BEMOL PORTO VELHO                   201       Tim          520
# 7            BEMOL PORTO VELHO                   201      Vivo          521
# 8   BEMOL PORTO VELHO SHOPPING                   202     Claro         2399
# 9   BEMOL PORTO VELHO SHOPPING                   202        Oi          602
# 10  BEMOL PORTO VELHO SHOPPING                   202       Tim          310
# 11  BEMOL PORTO VELHO SHOPPING                   202      Vivo          447
# 12        LOJA BEMOL ARIQUEMES                   206     Claro           45
# 13        LOJA BEMOL ARIQUEMES                   206        Oi           40
# 14        LOJA BEMOL ARIQUEMES                   206      Vivo           15
# 15  LOJA BEMOL FARMA ARIQUEMES                   613     Claro           90
# 16  LOJA BEMOL FARMA ARIQUEMES                   613        Oi           70
# 17  LOJA BEMOL FARMA ARIQUEMES                   613       Tim           35
# 18  LOJA BEMOL FARMA ARIQUEMES                   613      Vivo           35
# 19  LOJA BEMOL FARMA JI PARANA                   616     Claro          411
# 20  LOJA BEMOL FARMA JI PARANA                   616        Oi           95
# 21  LOJA BEMOL FARMA JI PARANA                   616       Tim           50
# 22  LOJA BEMOL FARMA JI PARANA                   616      Vivo           70
# 23        LOJA BEMOL JI-PARANA                   205     Claro          123

# %%
df_detalhamento4
# Out:
#                Loja  Escritório_de_Vendas Operadora  Valor_Bruto
# 0  BEMOL RIO BRANCO                   401     Claro          500
# 1  BEMOL RIO BRANCO                   401        Oi          375
# 2  BEMOL RIO BRANCO                   401       Tim          125
# 3  BEMOL RIO BRANCO                   401      Vivo          343

# %%
df_vendas
# Out:
#       Escritório_de_Vendas Operadora  Valor_Liquido
# 0                      101      Vivo           20.0
# 1                      101      Vivo           10.0
# 2                      101      Vivo           20.0
# 3                      101      Vivo           10.0
# 4                      101      Vivo           25.0
# ...                    ...       ...            ...
# 5108                   701     Claro           20.0
# 5109                   701     Claro           20.0
# 5110                   701     Claro           20.0
# 5111                   701     Claro           45.0
# 5112                   701     Claro           35.0
#
# [5113 rows x 3 columns]

# %%
df_detalhamento1.dtypes
# Out:
# Loja                    object
# Escritório_de_Vendas     int64
# Operadora               object
# Valor_Bruto              int64
# dtype: object

# %%
df_detalhamento2.dtypes
# Out:
# Loja                    object
# Escritório_de_Vendas     int64
# Operadora               object
# Valor_Bruto              int64
# dtype: object

# %%
df_detalhamento3.dtypes
# Out:
# Loja                    object
# Escritório_de_Vendas     int64
# Operadora               object
# Valor_Bruto              int64
# dtype: object

# %%
df_detalhamento4.dtypes
# Out:
# Loja                    object
# Escritório_de_Vendas     int64
# Operadora               object
# Valor_Bruto              int64
# dtype: object

# %%
df_vendas.dtypes
# Out:
# Escritório_de_Vendas      int64
# Operadora                object
# Valor_Liquido           float64
# dtype: object

# %%
df_vendas['Valor_Liquido'] = df_vendas['Valor_Liquido'].astype(int)

# %%
df_vendas.dtypes
# Out:
# Escritório_de_Vendas     int64
# Operadora               object
# Valor_Liquido            int64
# dtype: object

# %%
df_vendas
# Out:
#       Escritório_de_Vendas Operadora  Valor_Liquido
# 0                      101      Vivo             20
# 1                      101      Vivo             10
# 2                      101      Vivo             20
# 3                      101      Vivo             10
# 4                      101      Vivo             25
# ...                    ...       ...            ...
# 5108                   701     Claro             20
# 5109                   701     Claro             20
# 5110                   701     Claro             20
# 5111                   701     Claro             45
# 5112                   701     Claro             35
#
# [5113 rows x 3 columns]

# %%
df_detalhamento = pd.concat([df_detalhamento1,df_detalhamento2,df_detalhamento3,df_detalhamento4])

# %%
df_detalhamento
# Out:
#                     Loja  Escritório_de_Vendas Operadora  Valor_Bruto
# 0          BEMOL AVENIDA                   103     Claro         2651
# 1          BEMOL AVENIDA                   103        Oi         3309
# 2          BEMOL AVENIDA                   103       Tim         1550
# 3          BEMOL AVENIDA                   103      Vivo         4739
# 4          BEMOL BARROSO                   107     Claro         1495
# ..                   ...                   ...       ...          ...
# 23  LOJA BEMOL JI-PARANA                   205     Claro          123
# 0       BEMOL RIO BRANCO                   401     Claro          500
# 1       BEMOL RIO BRANCO                   401        Oi          375
# 2       BEMOL RIO BRANCO                   401       Tim          125
# 3       BEMOL RIO BRANCO                   401      Vivo          343
#
# [162 rows x 4 columns]

# %%
df_detalhamento = df_detalhamento.reset_index(drop = True)

# %%
df_detalhamento
# Out:
#                      Loja  Escritório_de_Vendas Operadora  Valor_Bruto
# 0           BEMOL AVENIDA                   103     Claro         2651
# 1           BEMOL AVENIDA                   103        Oi         3309
# 2           BEMOL AVENIDA                   103       Tim         1550
# 3           BEMOL AVENIDA                   103      Vivo         4739
# 4           BEMOL BARROSO                   107     Claro         1495
# ..                    ...                   ...       ...          ...
# 157  LOJA BEMOL JI-PARANA                   205     Claro          123
# 158      BEMOL RIO BRANCO                   401     Claro          500
# 159      BEMOL RIO BRANCO                   401        Oi          375
# 160      BEMOL RIO BRANCO                   401       Tim          125
# 161      BEMOL RIO BRANCO                   401      Vivo          343
#
# [162 rows x 4 columns]

# %%
df_vendas = df_vendas.reset_index(drop = True)

# %%
df_vendas
# Out:
#       Escritório_de_Vendas Operadora  Valor_Liquido
# 0                      101      Vivo             20
# 1                      101      Vivo             10
# 2                      101      Vivo             20
# 3                      101      Vivo             10
# 4                      101      Vivo             25
# ...                    ...       ...            ...
# 5108                   701     Claro             20
# 5109                   701     Claro             20
# 5110                   701     Claro             20
# 5111                   701     Claro             45
# 5112                   701     Claro             35
#
# [5113 rows x 3 columns]

# %%
df_vendas = df_vendas.groupby(['Escritório_de_Vendas', 'Operadora']).agg({'Valor_Liquido':'sum'}).reset_index(drop = False)

# %%
df_vendas
# Out:
#      Escritório_de_Vendas Operadora  Valor_Liquido
# 0                     101     Claro           1527
# 1                     101        Oi           1730
# 2                     101       Tim            975
# 3                     101      Vivo           3142
# 4                     103     Claro           2652
# ..                    ...       ...            ...
# 158                   618      Vivo            561
# 159                   701     Claro            140
# 160                   701        Oi             20
# 161                   701       Tim            135
# 162                   701      Vivo            304
#
# [163 rows x 3 columns]

# %%
df_relatorio_final = pd.merge(df_detalhamento, df_vendas,  on = ['Escritório_de_Vendas','Operadora'], how = 'left')

# %%
df_relatorio_final
# Out:
#                      Loja  Escritório_de_Vendas  ... Valor_Bruto  Valor_Liquido
# 0           BEMOL AVENIDA                   103  ...        2651           2652
# 1           BEMOL AVENIDA                   103  ...        3309           3309
# 2           BEMOL AVENIDA                   103  ...        1550           1550
# 3           BEMOL AVENIDA                   103  ...        4739           4739
# 4           BEMOL BARROSO                   107  ...        1495           1495
# ..                    ...                   ...  ...         ...            ...
# 157  LOJA BEMOL JI-PARANA                   205  ...         123            123
# 158      BEMOL RIO BRANCO                   401  ...         500            500
# 159      BEMOL RIO BRANCO                   401  ...         375            375
# 160      BEMOL RIO BRANCO                   401  ...         125            125
# 161      BEMOL RIO BRANCO                   401  ...         343            343
#
# [162 rows x 5 columns]

# %%
df_relatorio_final.fillna(0)
# Out:
#                      Loja  Escritório_de_Vendas  ... Valor_Bruto  Valor_Liquido
# 0           BEMOL AVENIDA                   103  ...        2651           2652
# 1           BEMOL AVENIDA                   103  ...        3309           3309
# 2           BEMOL AVENIDA                   103  ...        1550           1550
# 3           BEMOL AVENIDA                   103  ...        4739           4739
# 4           BEMOL BARROSO                   107  ...        1495           1495
# ..                    ...                   ...  ...         ...            ...
# 157  LOJA BEMOL JI-PARANA                   205  ...         123            123
# 158      BEMOL RIO BRANCO                   401  ...         500            500
# 159      BEMOL RIO BRANCO                   401  ...         375            375
# 160      BEMOL RIO BRANCO                   401  ...         125            125
# 161      BEMOL RIO BRANCO                   401  ...         343            343
#
# [162 rows x 5 columns]

# %%
df_relatorio_final = df_relatorio_final.drop(['Escritório_de_Vendas'], axis = 'columns')

# %%
df_relatorio_final
# Out:
#                      Loja Operadora  Valor_Bruto  Valor_Liquido
# 0           BEMOL AVENIDA     Claro         2651           2652
# 1           BEMOL AVENIDA        Oi         3309           3309
# 2           BEMOL AVENIDA       Tim         1550           1550
# 3           BEMOL AVENIDA      Vivo         4739           4739
# 4           BEMOL BARROSO     Claro         1495           1495
# ..                    ...       ...          ...            ...
# 157  LOJA BEMOL JI-PARANA     Claro          123            123
# 158      BEMOL RIO BRANCO     Claro          500            500
# 159      BEMOL RIO BRANCO        Oi          375            375
# 160      BEMOL RIO BRANCO       Tim          125            125
# 161      BEMOL RIO BRANCO      Vivo          343            343
#
# [162 rows x 4 columns]

# %%
def verificar_status(Valor_Liquido, Valor_Bruto):
  if (Valor_Liquido == Valor_Bruto):
    return 'Ok'
  else:
    return 'Apresenta Divergência'

# %%
df_relatorio_final['Status'] = df_relatorio_final.apply(lambda row: verificar_status(row['Valor_Liquido'], row['Valor_Bruto']), axis = 'columns')

# %%
df_relatorio_final
# Out:
#                      Loja Operadora  ...  Valor_Liquido                 Status
# 0           BEMOL AVENIDA     Claro  ...           2652  Apresenta Divergência
# 1           BEMOL AVENIDA        Oi  ...           3309                     Ok
# 2           BEMOL AVENIDA       Tim  ...           1550                     Ok
# 3           BEMOL AVENIDA      Vivo  ...           4739                     Ok
# 4           BEMOL BARROSO     Claro  ...           1495                     Ok
# ..                    ...       ...  ...            ...                    ...
# 157  LOJA BEMOL JI-PARANA     Claro  ...            123                     Ok
# 158      BEMOL RIO BRANCO     Claro  ...            500                     Ok
# 159      BEMOL RIO BRANCO        Oi  ...            375                     Ok
# 160      BEMOL RIO BRANCO       Tim  ...            125                     Ok
# 161      BEMOL RIO BRANCO      Vivo  ...            343                     Ok
#
# [162 rows x 5 columns]

# %%
print('Gerando Relatório...')
# Out:
# Gerando Relatório...

# %%
df_relatorio_final.columns = ['Loja', 'Operadora', 'Valor_Liquido', 'Valor_Bruto', 'Status']

# %%
df_relatorio_final
# Out:
#                      Loja Operadora  ...  Valor_Bruto                 Status
# 0           BEMOL AVENIDA     Claro  ...         2652  Apresenta Divergência
# 1           BEMOL AVENIDA        Oi  ...         3309                     Ok
# 2           BEMOL AVENIDA       Tim  ...         1550                     Ok
# 3           BEMOL AVENIDA      Vivo  ...         4739                     Ok
# 4           BEMOL BARROSO     Claro  ...         1495                     Ok
# ..                    ...       ...  ...          ...                    ...
# 157  LOJA BEMOL JI-PARANA     Claro  ...          123                     Ok
# 158      BEMOL RIO BRANCO     Claro  ...          500                     Ok
# 159      BEMOL RIO BRANCO        Oi  ...          375                     Ok
# 160      BEMOL RIO BRANCO       Tim  ...          125                     Ok
# 161      BEMOL RIO BRANCO      Vivo  ...          343                     Ok
#
# [162 rows x 5 columns]

# %%
df_relatorio_final.to_csv('Relatório_Final.csv', sep = ';')

# %%
writer = pd.ExcelWriter('Relatório_Final.xlsx')

df_relatorio_final.to_excel(writer, sheet_name = 'Conciliação', index = False)

writer.save()

# %%
print('Relatório Gerado com Sucesso!')
# Out:
# Relatório Gerado com Sucesso!

# %%
input()
